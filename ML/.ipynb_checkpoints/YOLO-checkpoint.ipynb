# %%
from PIL import Image
import numpy as np
import pandas as pd
import random
from os import listdir
# %matplotlib inline
import matplotlib.pyplot as plt

from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.models import Model, Sequential
from keras.layers import *
import keras.backend as K
import keras.optimizers as Optimizers
import keras.callbacks
# Out:
# C:\Users\Rock_\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# ## YOLO

# %%
grid_w = 7
grid_h = 3

def load_photos(directory):
    images = []
    x_labels_loc = []
    y_labels_loc = []
    class_labels_loc = []
    dir_list = listdir(directory)
    random.shuffle(dir_list)
    for name in dir_list:
        filename = directory + '/' + name
        # load an image from file
        image = load_img(filename)
        # convert the image pixels to a numpy array
        image = img_to_array(image)
        images.append(image)
        # get labels
        x_labels_loc.append(int(float(name.split('_')[1]) * (grid_w)))
        y_labels_loc.append(int(float(name.split('_')[2].split('.png')[0]) * (grid_h)))
    return images, x_labels_loc, y_labels_loc

# %%
dataset = "Yolo_Datas/"

# load images from both train and test groups
directory = dataset + 'Train'
images, x_labels_loc, y_labels_loc = load_photos(directory)
nb_images = len(images)
print('Loaded Images and labels for training: %d' % nb_images)
# Out:
# Loaded Images and labels for training: 1660

# %%
#Normalise images
images = np.array(images)
images = images
images /= 255.0

#convert datas to dummyvalues
x_labels_loc = np.array(keras.utils.to_categorical((x_labels_loc), num_classes= grid_w))
y_labels_loc = np.array(keras.utils.to_categorical((y_labels_loc), num_classes= grid_h))

# %%
idx = 470

print(x_labels_loc[idx])
print(y_labels_loc[idx])
print(images[idx].shape)
plt.imshow(images[idx])

for line in range(1, grid_h):
    plt.axhline(line * images[idx].shape[0] / grid_h)
for col in range(1, grid_w):
    plt.axvline(col * images[idx].shape[1] / grid_w)
# Out:
# [0. 0. 1. 0. 0. 0. 0.]
# [0. 1. 0.]
# (240, 320, 3)

# %%
K.clear_session()

img_in = Input(shape=images[0].shape, name='img_in')
x = img_in

x = Convolution2D(16, (8,8), strides=(4,4), use_bias=False)(x)       
x = BatchNormalization()(x)
x = Activation("relu")(x)
x = Dropout(.4)(x)
x = Convolution2D(8, (4,4), strides=(2,2), use_bias=False)(x)       
x = BatchNormalization()(x)
x = Activation("relu")(x)
x = Dropout(.2)(x)
x = Convolution2D(4, (2,2), use_bias=False)(x)       
x = BatchNormalization()(x)
x = Activation("relu")(x)
x = Dropout(.2)(x)

x = Flatten(name='flattened')(x)

x = Dense(1000, use_bias=False)(x) 
x = BatchNormalization()(x)
x = Activation("relu")(x)
x = Dropout(.4)(x)
x = Dense(500, use_bias=False)(x) 
x = BatchNormalization()(x)
x = Activation("relu")(x)
x = Dropout(.2)(x)
x = Dense(50, use_bias=False)(x)  
x = BatchNormalization()(x)
x = Activation("relu")(x)

out_x = Dense(x_labels_loc.shape[1], activation='softmax')(x)
out_y = Dense(y_labels_loc.shape[1], activation='softmax')(x)

# Compile Model
model = Model(inputs=img_in, outputs=[out_x, out_y])
model.compile(loss='categorical_crossentropy', optimizer='adadelta', metrics=['accuracy'])

model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# img_in (InputLayer)             (None, 240, 320, 3)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 59, 79, 16)   3072        img_in[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 59, 79, 16)   64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 59, 79, 16)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 59, 79, 16)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 28, 38, 8)    2048        dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 28, 38, 8)    32          conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 28, 38, 8)    0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 28, 38, 8)    0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 27, 37, 4)    128         dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 27, 37, 4)    16          conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 27, 37, 4)    0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 27, 37, 4)    0           activation_3[0][0]
# __________________________________________________________________________________________________
# flattened (Flatten)             (None, 3996)         0           dropout_3[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1000)         3996000     flattened[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 1000)         4000        dense_1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 1000)         0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 1000)         0           activation_4[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 500)          500000      dropout_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 500)          2000        dense_2[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 500)          0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 500)          0           activation_5[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 50)           25000       dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 50)           200         dense_3[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 50)           0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 7)            357         activation_6[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 3)            153         activation_6[0][0]
# ==================================================================================================
# Total params: 4,533,070
# Trainable params: 4,529,914
# Non-trainable params: 3,156
# __________________________________________________________________________________________________

# %%
model_name="model_YOLO_2.h5"
#save best model if model improved
best_checkpoint = keras.callbacks.ModelCheckpoint(model_name, monitor='val_loss', verbose=1, save_best_only=True, mode='min')

# %%
h = model.fit(images, [x_labels_loc, y_labels_loc], batch_size=32, epochs=10, validation_split=0.2, verbose=1, callbacks=[best_checkpoint])
# Out:
# Train on 1328 samples, validate on 332 samples
# Epoch 1/10
# 1328/1328 [==============================] - 194s 146ms/step - loss: 0.1584 - dense_4_loss: 0.1216 - dense_5_loss: 0.0368 - dense_4_acc: 0.9623 - dense_5_acc: 0.9864 - val_loss: 1.0444 - val_dense_4_loss: 0.6467 - val_dense_5_loss: 0.3977 - val_dense_4_acc: 0.7861 - val_dense_5_acc: 0.7922
#
# Epoch 00001: val_loss did not improve
# Epoch 2/10
# 1328/1328 [==============================] - 187s 141ms/step - loss: 0.1626 - dense_4_loss: 0.1331 - dense_5_loss: 0.0295 - dense_4_acc: 0.9518 - dense_5_acc: 0.9917 - val_loss: 0.6902 - val_dense_4_loss: 0.5203 - val_dense_5_loss: 0.1698 - val_dense_4_acc: 0.8313 - val_dense_5_acc: 0.9548
#
# Epoch 00002: val_loss did not improve
# Epoch 3/10
# 1328/1328 [==============================] - 167s 126ms/step - loss: 0.1488 - dense_4_loss: 0.1128 - dense_5_loss: 0.0360 - dense_4_acc: 0.9623 - dense_5_acc: 0.9857 - val_loss: 3.1965 - val_dense_4_loss: 1.4201 - val_dense_5_loss: 1.7764 - val_dense_4_acc: 0.5241 - val_dense_5_acc: 0.5331
#
# Epoch 00003: val_loss did not improve
# Epoch 4/10
# 1328/1328 [==============================] - 172s 130ms/step - loss: 0.1353 - dense_4_loss: 0.1002 - dense_5_loss: 0.0351 - dense_4_acc: 0.9684 - dense_5_acc: 0.9827 - val_loss: 0.9002 - val_dense_4_loss: 0.5997 - val_dense_5_loss: 0.3006 - val_dense_4_acc: 0.8193 - val_dense_5_acc: 0.9127
#
# Epoch 00004: val_loss did not improve
# Epoch 5/10
# 1328/1328 [==============================] - 170s 128ms/step - loss: 0.1555 - dense_4_loss: 0.1205 - dense_5_loss: 0.0350 - dense_4_acc: 0.9533 - dense_5_acc: 0.9872 - val_loss: 0.9092 - val_dense_4_loss: 0.6213 - val_dense_5_loss: 0.2879 - val_dense_4_acc: 0.7922 - val_dense_5_acc: 0.9157
#
# Epoch 00005: val_loss did not improve
# Epoch 6/10
# 1328/1328 [==============================] - 152s 115ms/step - loss: 0.1326 - dense_4_loss: 0.0978 - dense_5_loss: 0.0349 - dense_4_acc: 0.9623 - dense_5_acc: 0.9910 - val_loss: 0.6471 - val_dense_4_loss: 0.4890 - val_dense_5_loss: 0.1580 - val_dense_4_acc: 0.8494 - val_dense_5_acc: 0.9578
#
# Epoch 00006: val_loss did not improve
# Epoch 7/10
# 1328/1328 [==============================] - 184s 139ms/step - loss: 0.1317 - dense_4_loss: 0.1063 - dense_5_loss: 0.0254 - dense_4_acc: 0.9661 - dense_5_acc: 0.9932 - val_loss: 14.8226 - val_dense_4_loss: 2.6392 - val_dense_5_loss: 12.1835 - val_dense_4_acc: 0.3163 - val_dense_5_acc: 0.2319
#
# Epoch 00007: val_loss did not improve
# Epoch 8/10
# 1328/1328 [==============================] - 176s 133ms/step - loss: 0.1103 - dense_4_loss: 0.0881 - dense_5_loss: 0.0222 - dense_4_acc: 0.9721 - dense_5_acc: 0.9932 - val_loss: 0.6831 - val_dense_4_loss: 0.4685 - val_dense_5_loss: 0.2147 - val_dense_4_acc: 0.8554 - val_dense_5_acc: 0.9337
#
# Epoch 00008: val_loss did not improve
# Epoch 9/10
# 1328/1328 [==============================] - 182s 137ms/step - loss: 0.1327 - dense_4_loss: 0.1075 - dense_5_loss: 0.0252 - dense_4_acc: 0.9616 - dense_5_acc: 0.9955 - val_loss: 5.9221 - val_dense_4_loss: 1.1791 - val_dense_5_loss: 4.7430 - val_dense_4_acc: 0.5934 - val_dense_5_acc: 0.2892
#
# Epoch 00009: val_loss did not improve
# Epoch 10/10
# 1328/1328 [==============================] - 174s 131ms/step - loss: 0.1359 - dense_4_loss: 0.0994 - dense_5_loss: 0.0365 - dense_4_acc: 0.9706 - dense_5_acc: 0.9864 - val_loss: 0.5908 - val_dense_4_loss: 0.4565 - val_dense_5_loss: 0.1343 - val_dense_4_acc: 0.8524 - val_dense_5_acc: 0.9608
#
# Epoch 00010: val_loss improved from 0.61606 to 0.59079, saving model to model_YOLO_2.h5

# %%
#print History graph
historydf = pd.DataFrame(h.history, index=h.epoch)
historydf.plot(ylim=(0,1))
